# %%
import pandas as pd
import requests
import pprint
import asyncio

# %%
m = requests.get('https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/list')
subIdAe = m.json()
df = pd.DataFrame(subIdAe['data'],columns=['subject_Id_AE'])
df.tail()
# Out:
#      subject_Id_AE
# 723       17954820
# 724       17956076
# 725       18042999
# 726       18282353
# 727       18291148

# %%
n = requests.get('https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/cm/subject/list')
subIdCm = n.json()
df1 = pd.DataFrame(subIdCm['data'],columns=['subject_Id_CM'])
df1.tail()
# Out:
#      subject_Id_CM
# 717       55325218
# 718       55334564
# 719       55392353
# 720       55396342
# 721       55397989

# %%
records_ae = df['subject_Id_AE'][721]
records_ae
# Out:
# 17866564

# %%
records_cm = df1['subject_Id_CM'][721]
records_cm
# Out:
# 55397989

# %%
ae_ae_data = requests.get('https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/{}/list'.format(records_ae))
ae_ae_data = ae_ae_data.json()
dataframe_ae = pd.DataFrame(ae_ae_data['data'])
dataframe_ae
# Out:
#       studyid  siteid    subjid  subjectid  visitindex visitnam formname  \
# 0   StudyHack    5308  53085005   17866564           1     AECM    AE202
# 1   StudyHack    5308  53085005   17866564           1     AECM    AE202
# 2   StudyHack    5308  53085005   17866564           1     AECM    AE202
# 3   StudyHack    5308  53085005   17866564           1     AECM    AE202
# 4   StudyHack    5308  53085005   17866564           1     AECM    AE202
# 5   StudyHack    5308  53085005   17866564           1     AECM    AE202
# 6   StudyHack    5308  53085005   17866564           1     AECM    AE202
# 7   StudyHack    5308  53085005   17866564           1     AECM    AE202
# 8   StudyHack    5308  53085005   17866564           1     AECM    AE202
# 9   StudyHack    5308  53085005   17866564           1     AECM    AE202
# 10  StudyHack    5308  53085005   17866564           1     AECM    AE202
#
#     formid  formidx     formindex  ... aeacn3_c            aeacn3 aeacn3_1_c  \
# 0    38768        1  6.040000e+14  ...      NaN                          2.0
# 1    38768        2  6.160000e+14  ...      NaN                          6.0
# 2    38768        3  6.160000e+14  ...      NaN                          2.0
# 3    38768        4  6.160000e+14  ...      2.0  DOSE NOT CHANGED        NaN
# 4    38768        5  6.160000e+14  ...      NaN                          2.0
# 5    38768        6  6.160000e+14  ...      2.0  DOSE NOT CHANGED        NaN
# 6    38768        7  6.160000e+14  ...      NaN                          2.0
# 7    38768        8  6.160000e+14  ...      2.0  DOSE NOT CHANGED        NaN
# 8    38768        9  6.160000e+14  ...      NaN                          6.0
# 9    38768       10  6.160000e+14  ...      NaN                          6.0
# 10   38768       11  6.160000e+14  ...      NaN                          6.0
#
#             aeacn3_1  aerelnst_c aerelnst aerelnst_nd  \
# 0   DOSE NOT CHANGED           3    OTHER
# 1     NOT APPLICABLE           3    OTHER
# 2   DOSE NOT CHANGED           3    OTHER
# 3                              3    OTHER
# 4   DOSE NOT CHANGED           3    OTHER
# 5                              3    OTHER
# 6   DOSE NOT CHANGED           3    OTHER
# 7                              3    OTHER
# 8     NOT APPLICABLE           3    OTHER
# 9     NOT APPLICABLE           3    OTHER
# 10    NOT APPLICABLE           3    OTHER
#
#                           aerelt aeout_c               aeout
# 0                    food intake       3  RECOVERED/RESOLVED
# 1                    FOOD INTAKE       3  RECOVERED/RESOLVED
# 2       IMMUNOCOMPROMISED PATIEN       3  RECOVERED/RESOLVED
# 3    POSTCHEMOTHERAPY LEUKOPENIA       3  RECOVERED/RESOLVED
# 4   POSTCHEMOTHERAPY NEUTROPENIA       3  RECOVERED/RESOLVED
# 5               POSTCHEMOTHERAPY       3  RECOVERED/RESOLVED
# 6               POSTCHEMOTHERAPY       3  RECOVERED/RESOLVED
# 7              PODSTCHEMOTHERAPY       3  RECOVERED/RESOLVED
# 8                         UNKNOW       3  RECOVERED/RESOLVED
# 9             MEDULLARY RECOVERY       3  RECOVERED/RESOLVED
# 10              THROMBOCYTOPENIA       3  RECOVERED/RESOLVED
#
# [11 rows x 88 columns]

# %%
cm_cm_data = requests.get('https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/cm/subject/{}/list'.format(records_cm))
cm_cm_data = cm_cm_data.json()
dataframe_cm = pd.DataFrame(cm_cm_data['data'])
dataframe_cm[dataframe_cm['cmprior']=='YES']['subjectid']
# Out:
# 5     55397989
# 6     55397989
# 7     55397989
# 8     55397989
# 9     55397989
# 10    55397989
# 13    55397989
# 16    55397989
# 22    55397989
# Name: subjectid, dtype: int64

# %%
for j in range(len(df1)):
    cm_cm_data = requests.get('https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/cm/subject/{}/list'.format(df1['subject_Id_CM'][j]))
    cm_cm_data = cm_cm_data.json()
    dataframe_cm = pd.DataFrame(cm_cm_data['data'])
    
    type1 = dataframe_cm[dataframe_cm['cmprior']=='YES'][['subjectid','formidx','formname','formid']]
    type1 = pd.DataFrame(type1)
    
    for i in range(len(type1)):
        formid = list(type1['formid'])[i]
        formidx = list(type1['formidx'])[i]
        formname = list(type1['formid'])[i]
        subjectid = list(type1['subjectid'])[i]
        print(formidx,subjectid,formid,formname)

        postReq = {
            "email_address": "naveen.rm.551@gmail.com",
            "formname": str(formname),
            "formid": str(formid),
            "formidx": str(formidx),
            "type": "TYPE1",
            "subjectid": str(subjectid)
        }
        print(postReq)

        post1 = requests.post('https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/query',data = postReq)
        print(post1)
    
    type2 = dataframe_cm[dataframe_cm['cmaeno']!=''][['subjectid','formidx','formname','formid']]
    type2 = pd.DataFrame(type2)
    
    for i in range(len(type2)):
        formid = list(type2['formid'])[i]
        formidx = list(type2['formidx'])[i]
        formname = list(type2['formid'])[i]
        subjectid = list(type2['subjectid'])[i]
        print(formidx,subjectid,formid,formname)

        postReq = {
            "email_address": "naveen.rm.551@gmail.com",
            "formname": str(formname),
            "formid": str(formid),
            "formidx": str(formidx),
            "type": "TYPE2",
            "subjectid": str(subjectid)
        }
        print(postReq)

        post2 = requests.post('https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/query',data = postReq)
        print(post2)
        
    type4 = dataframe_cm[['subjectid','formidx','formname','formid','cmtrt']]
    
    for i in range(len(type4)-1):
        if( list(dataframe_cm['cmtrt'])[i] == list(dataframe_cm['cmtrt'])[i-1] ):
            formid = list(type4['formid'])[i]
            formidx = list(type4['formidx'])[i]
            formname = list(type4['formid'])[i]
            subjectid = list(type4['subjectid'])[i]
            print(formidx,subjectid,formid,formname)

            postReq = {
                "email_address": "naveen.rm.551@gmail.com",
                "formname": str(formname),
                "formid": str(formid),
                "formidx": str(formidx),
                "type": "TYPE4",
                "subjectid": str(subjectid)
            }
            print(postReq)

            post3 = requests.post('https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/query',data = postReq)
            print(post3)
# Out:
# 1 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '1', 'type': 'TYPE1', 'subjectid': '76809'}
# <Response [500]>
# 2 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '2', 'type': 'TYPE1', 'subjectid': '76809'}
# <Response [500]>
# 3 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '3', 'type': 'TYPE1', 'subjectid': '76809'}
# <Response [500]>
# 4 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '4', 'type': 'TYPE1', 'subjectid': '76809'}
# <Response [500]>
# 5 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '5', 'type': 'TYPE1', 'subjectid': '76809'}
# <Response [500]>
# 6 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '6', 'type': 'TYPE1', 'subjectid': '76809'}
# <Response [500]>
# 8 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '8', 'type': 'TYPE1', 'subjectid': '76809'}
# <Response [500]>
# 9 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '9', 'type': 'TYPE1', 'subjectid': '76809'}
# <Response [500]>
# 50 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '50', 'type': 'TYPE1', 'subjectid': '76809'}
# <Response [500]>
# 17 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '17', 'type': 'TYPE1', 'subjectid': '76809'}
# <Response [500]>
# 18 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '18', 'type': 'TYPE1', 'subjectid': '76809'}
# <Response [500]>
# 19 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '19', 'type': 'TYPE1', 'subjectid': '76809'}
# <Response [500]>
# 20 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '20', 'type': 'TYPE1', 'subjectid': '76809'}
# <Response [500]>
# 21 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '21', 'type': 'TYPE1', 'subjectid': '76809'}
# <Response [500]>
# 22 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '22', 'type': 'TYPE1', 'subjectid': '76809'}
# <Response [500]>
# 30 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '30', 'type': 'TYPE1', 'subjectid': '76809'}
# <Response [500]>
# 31 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '31', 'type': 'TYPE1', 'subjectid': '76809'}
# <Response [500]>
# 42 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '42', 'type': 'TYPE1', 'subjectid': '76809'}
# <Response [500]>
# 76 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '76', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 78 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '78', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 80 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '80', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 84 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '84', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 85 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '85', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 89 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '89', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 90 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '90', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 500 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '500', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 504 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '504', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 16 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '16', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 23 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '23', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 24 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '24', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 25 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '25', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 26 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '26', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 29 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '29', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 32 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '32', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 33 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '33', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 38 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '38', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 39 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '39', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 40 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '40', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 41 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '41', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 46 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '46', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 48 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '48', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 59 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '59', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 60 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '60', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 62 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '62', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 70 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '70', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 71 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '71', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 72 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '72', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 73 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '73', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 74 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '74', 'type': 'TYPE2', 'subjectid': '76809'}
# <Response [500]>
# 88 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '88', 'type': 'TYPE4', 'subjectid': '76809'}
# <Response [500]>
# 504 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '504', 'type': 'TYPE4', 'subjectid': '76809'}
# <Response [500]>
# 4 76809 32993 32993
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '32993', 'formid': '32993', 'formidx': '4', 'type': 'TYPE4', 'subjectid': '76809'}
# <Response [500]>
# 6 76809 32993 32993
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '32993', 'formid': '32993', 'formidx': '6', 'type': 'TYPE4', 'subjectid': '76809'}
# <Response [500]>
# 8 76809 32993 32993
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '32993', 'formid': '32993', 'formidx': '8', 'type': 'TYPE4', 'subjectid': '76809'}
# <Response [500]>
# 44 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '44', 'type': 'TYPE4', 'subjectid': '76809'}
# <Response [500]>
# 73 76809 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '73', 'type': 'TYPE4', 'subjectid': '76809'}
# <Response [500]>
# 3 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '3', 'type': 'TYPE1', 'subjectid': '130301'}
# <Response [500]>
# 4 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '4', 'type': 'TYPE1', 'subjectid': '130301'}
# <Response [500]>
# 9 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '9', 'type': 'TYPE1', 'subjectid': '130301'}
# <Response [500]>
# 50 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '50', 'type': 'TYPE1', 'subjectid': '130301'}
# <Response [500]>
# 51 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '51', 'type': 'TYPE1', 'subjectid': '130301'}
# <Response [500]>
# 52 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '52', 'type': 'TYPE1', 'subjectid': '130301'}
# <Response [500]>
# 13 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '13', 'type': 'TYPE1', 'subjectid': '130301'}
# <Response [500]>
# 53 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '53', 'type': 'TYPE1', 'subjectid': '130301'}
# <Response [500]>
# 32 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '32', 'type': 'TYPE1', 'subjectid': '130301'}
# <Response [500]>
# 1 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '1', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 5 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '5', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 6 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '6', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 7 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '7', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 8 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '8', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 19 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '19', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 20 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '20', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 24 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '24', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 29 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '29', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 30 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '30', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 31 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '31', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 42 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '42', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 52 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '52', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 61 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '61', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 62 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '62', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 64 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '64', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 71 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '71', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 72 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '72', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 75 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '75', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 76 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '76', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 77 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '77', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 79 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '79', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 82 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '82', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 85 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '85', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 87 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '87', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 89 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '89', 'type': 'TYPE2', 'subjectid': '130301'}
# <Response [500]>
# 19 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '19', 'type': 'TYPE4', 'subjectid': '130301'}
# <Response [500]>
# 36 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '36', 'type': 'TYPE4', 'subjectid': '130301'}
# <Response [500]>
# 39 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '39', 'type': 'TYPE4', 'subjectid': '130301'}
# <Response [500]>
# 41 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '41', 'type': 'TYPE4', 'subjectid': '130301'}
# <Response [500]>
# 43 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '43', 'type': 'TYPE4', 'subjectid': '130301'}
# <Response [500]>
# 45 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '45', 'type': 'TYPE4', 'subjectid': '130301'}
# <Response [500]>
# 72 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '72', 'type': 'TYPE4', 'subjectid': '130301'}
# <Response [500]>
# 78 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '78', 'type': 'TYPE4', 'subjectid': '130301'}
# <Response [500]>
# 79 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '79', 'type': 'TYPE4', 'subjectid': '130301'}
# <Response [500]>
# 80 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '80', 'type': 'TYPE4', 'subjectid': '130301'}
# <Response [500]>
# 83 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '83', 'type': 'TYPE4', 'subjectid': '130301'}
# <Response [500]>
# 86 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '86', 'type': 'TYPE4', 'subjectid': '130301'}
# <Response [500]>
# 88 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '88', 'type': 'TYPE4', 'subjectid': '130301'}
# <Response [500]>
# 89 130301 38623 38623
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38623', 'formid': '38623', 'formidx': '89', 'type': 'TYPE4', 'subjectid': '130301'}
# <Response [500]>

# %%
postReq = {
  "email_address": "naveen.rm.551@gmail.com",
  "formname": "AE202",
  "formid": "38768",
  "formidx": "43",
  "type": "TYPE1",
  "subjectid": "TYPE1"
}

# %%
dataframe.columns
# Out:
# Index(['studyid', 'siteid', 'subjid', 'subjectid', 'visitid', 'visitidx',
#        'visitnam', 'formname', 'formid', 'formidx', 'formindex', 'cmyn',
#        'cmyn_c', 'cmcat_c', 'cmcat_nd', 'cmscat', 'cmscat_c', 'cmpresp',
#        'cmpresp_c', 'cmpresp_nd', 'cmtrt', 'cmtrt_nd', 'cmrgm', 'cmrgm_nd',
#        'cmindc', 'cmaeno', 'cmaer', 'cmaer_c', 'cmdostot', 'cmdostot_nd',
#        'cmdosu', 'cmdosu_c', 'cmdosu_nd', 'cmroute', 'cmroute_c', 'cmprior',
#        'cmprior_c', 'cmstdat', 'cmstdat_dtr', 'cmstdat_dts', 'cmendat',
#        'cmendat_dtr', 'cmendat_dts', 'cmongo', 'cmongo_c', 'cmongo_nd',
#        'compterm', 'cmdecod', 'siteno'],
#       dtype='object')

# %%
len(dataframe[dataframe['cmaeno']=='']['cmaeno'])
# Out:
# 28

# %%
for j in range(len(df)):
    ae_ae_data = requests.get('https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/{}/list'.format(df['subject_Id_AE'][j]))
    ae_ae_data = ae_ae_data.json()
    dataframe_ae = pd.DataFrame(ae_ae_data['data'])
    
    type3 = dataframe_ae[['subjectid','formidx','formname','formid','aeterm']]
    
    for i in range(len(type3)-1):
        if( list(dataframe_ae['aeterm'])[i] == list(dataframe_ae['aeterm'])[i+1] ):
            formid = list(type3['formid'])[i]
            formidx = list(type3['formidx'])[i]
            formname = list(type3['formid'])[i]
            subjectid = list(type3['subjectid'])[i]
            print(formidx,subjectid,formid,formname)

            postReq = {
                "email_address": "naveen.rm.551@gmail.com",
                "formname": str(formname),
                "formid": str(formid),
                "formidx": str(formidx),
                "type": "TYPE3",
                "subjectid": str(subjectid)
            }
            print(postReq)

            post3 = requests.post('https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/query',data = postReq)
            print(post3)
# Out:
# 20 76809 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '20', 'type': 'TYPE3', 'subjectid': '76809'}
# <Response [500]>
# 27 76809 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '27', 'type': 'TYPE3', 'subjectid': '76809'}
# <Response [500]>
# 28 76809 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '28', 'type': 'TYPE3', 'subjectid': '76809'}
# <Response [500]>
# 29 76809 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '29', 'type': 'TYPE3', 'subjectid': '76809'}
# <Response [500]>
# 31 76809 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '31', 'type': 'TYPE3', 'subjectid': '76809'}
# <Response [500]>
# 32 76809 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '32', 'type': 'TYPE3', 'subjectid': '76809'}
# <Response [500]>
# 35 76809 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '35', 'type': 'TYPE3', 'subjectid': '76809'}
# <Response [500]>
# 36 76809 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '36', 'type': 'TYPE3', 'subjectid': '76809'}
# <Response [500]>
# 42 76809 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '42', 'type': 'TYPE3', 'subjectid': '76809'}
# <Response [500]>
# 43 76809 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '43', 'type': 'TYPE3', 'subjectid': '76809'}
# <Response [500]>
# 12 76809 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '12', 'type': 'TYPE3', 'subjectid': '76809'}
# <Response [500]>
# 44 105792 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '44', 'type': 'TYPE3', 'subjectid': '105792'}
# <Response [500]>
# 46 105792 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '46', 'type': 'TYPE3', 'subjectid': '105792'}
# <Response [500]>
# 48 105792 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '48', 'type': 'TYPE3', 'subjectid': '105792'}
# <Response [500]>
# 52 105792 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '52', 'type': 'TYPE3', 'subjectid': '105792'}
# <Response [500]>
# 53 105792 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '53', 'type': 'TYPE3', 'subjectid': '105792'}
# <Response [500]>
# 55 105792 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '55', 'type': 'TYPE3', 'subjectid': '105792'}
# <Response [500]>
# 56 105792 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '56', 'type': 'TYPE3', 'subjectid': '105792'}
# <Response [500]>
# 57 105792 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '57', 'type': 'TYPE3', 'subjectid': '105792'}
# <Response [500]>
# 60 105792 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '60', 'type': 'TYPE3', 'subjectid': '105792'}
# <Response [500]>
# 64 105792 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '64', 'type': 'TYPE3', 'subjectid': '105792'}
# <Response [500]>
# 66 105792 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '66', 'type': 'TYPE3', 'subjectid': '105792'}
# <Response [500]>
# 74 105792 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '74', 'type': 'TYPE3', 'subjectid': '105792'}
# <Response [500]>
# 10 105792 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '10', 'type': 'TYPE3', 'subjectid': '105792'}
# <Response [500]>
# 26 105792 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '26', 'type': 'TYPE3', 'subjectid': '105792'}
# <Response [500]>
# 29 105792 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '29', 'type': 'TYPE3', 'subjectid': '105792'}
# <Response [500]>
# 39 105792 38768 38768
# {'email_address': 'naveen.rm.551@gmail.com', 'formname': '38768', 'formid': '38768', 'formidx': '39', 'type': 'TYPE3', 'subjectid': '105792'}
# <Response [500]>

# %%
dataframe_cm.columns
# Out:
# Index(['studyid', 'siteid', 'subjid', 'subjectid', 'visitid', 'visitidx',
#        'visitnam', 'formname', 'formid', 'formidx', 'formindex', 'cmyn',
#        'cmyn_c', 'cmcat_c', 'cmcat_nd', 'cmscat', 'cmscat_c', 'cmpresp',
#        'cmpresp_c', 'cmpresp_nd', 'cmtrt', 'cmtrt_nd', 'cmrgm', 'cmrgm_nd',
#        'cmindc', 'cmaeno', 'cmaer', 'cmaer_c', 'cmdostot', 'cmdostot_nd',
#        'cmdosu', 'cmdosu_c', 'cmdosu_nd', 'cmroute', 'cmroute_c', 'cmprior',
#        'cmprior_c', 'cmstdat', 'cmstdat_dtr', 'cmstdat_dts', 'cmendat',
#        'cmendat_dtr', 'cmendat_dts', 'cmongo', 'cmongo_c', 'cmongo_nd',
#        'compterm', 'cmdecod', 'siteno'],
#       dtype='object')

# %%
dataframe_ae.columns
# Out:
# Index(['studyid', 'siteid', 'subjid', 'subjectid', 'visitindex', 'visitnam',
#        'formname', 'formid', 'formidx', 'formindex', 'dov', 'aemeyn',
#        'aemeyn_c', 'aecat', 'aecat_c', 'aeterm', 'aemedrg', 'aeinpkg',
#        'aestdat', 'aestdat_dts', 'aestdat_nd', 'aestdme', 'aestdme_c',
#        'aeendat', 'aeendat_dts', 'aeendat_nd', 'aedis', 'aedis_c', 'aemerae',
#        'aemerae_c', 'aespid', 'aendgiv', 'aendgiv_c', 'aecmgiv', 'aecmgiv_c',
#        'aecmgiv_nd', 'aerefid', 'compterm', 'aellt', 'aedecod', 'aehlt',
#        'aehlgt', 'aesoc', 'aemedrg_c', 'aespid_1', 'aeyn', 'aeyn_c',
#        'aeongo_c', 'aeongo', 'aetoxgr_c', 'aetoxgr', 'aeser_c', 'aeser',
#        'aerme_c', 'aerme', 'aetrt1', 'aetrt3_c', 'aerel1_c', 'aerel1',
#        'aerel1_nd', 'aeacn1_c', 'aeacn1', 'aeacn1_1_c', 'aeacn1_1', 'aetrt2',
#        'aetrt2_nd', 'aetrt2_c', 'aerel2_c', 'aerel2', 'aerel2_nd', 'aeacn2_c',
#        'aeacn2', 'aeacn2_1_c', 'aeacn2_1', 'aetrt3', 'aetrt1_c', 'aerel3_c',
#        'aerel3', 'aeacn3_c', 'aeacn3', 'aeacn3_1_c', 'aeacn3_1', 'aerelnst_c',
#        'aerelnst', 'aerelnst_nd', 'aerelt', 'aeout_c', 'aeout'],
#       dtype='object')
